# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunKedar05/MySQL-Batch-30th-June-2025-B7-MW/blob/main/CompanyDatasetAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/company_employees..csv')
df.head()
# Out:
#    ID          Name  Age Department            Role  Salary  YearsAtCompany  \
# 0   1   Arjun Kumar   29         IT       Developer   75000               3
# 1   2  Priya Sharma   32         HR         Manager   85000               5
# 2   3   Rahul Verma   28    Finance         Analyst   65000               2
# 3   4  Anjali Singh   35         IT  Lead Developer  105000               7
# 4   5  Manish Gupta   30  Marketing       Executive   55000               4
#
#    PerformanceScore   Location    HireDate
# 0               8.5  Bangalore  2019-04-15
# 1               9.0     Mumbai  2017-06-10
# 2               7.5      Delhi  2021-01-12
# 3               9.5  Hyderabad  2016-09-22
# 4               8.0    Chennai  2018-03-18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                50 non-null     int64
#  1   Name              50 non-null     object
#  2   Age               50 non-null     int64
#  3   Department        50 non-null     object
#  4   Role              50 non-null     object
#  5   Salary            50 non-null     int64
#  6   YearsAtCompany    50 non-null     int64
#  7   PerformanceScore  50 non-null     float64
#  8   Location          50 non-null     object
#  9   HireDate          50 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 4.0+ KB

# %%
df.head(10)
# Out:
#    ID           Name  Age Department            Role  Salary  YearsAtCompany  \
# 0   1    Arjun Kumar   29         IT       Developer   75000               3
# 1   2   Priya Sharma   32         HR         Manager   85000               5
# 2   3    Rahul Verma   28    Finance         Analyst   65000               2
# 3   4   Anjali Singh   35         IT  Lead Developer  105000               7
# 4   5   Manish Gupta   30  Marketing       Executive   55000               4
# 5   6     Sneha Jain   27         IT       Developer   72000               2
# 6   7   Vikram Reddy   33    Finance         Manager   95000               6
# 7   8     Divya Nair   31         HR       Recruiter   65000               3
# 8   9   Aditya Mehra   29         IT       Developer   78000               4
# 9  10  Ritika Kapoor   34  Marketing         Manager   88000               6
#
#    PerformanceScore   Location    HireDate
# 0               8.5  Bangalore  2019-04-15
# ...

# %%
df.tail(5)
# Out:
#     ID             Name  Age Department            Role  Salary  \
# 45  46      Arjun Mehra   32         IT       Developer   77000
# 46  47     Ananya Gupta   29  Marketing       Executive   55000
# 47  48  Siddharth Verma   34    Finance  Senior Analyst   98000
# 48  49     Divya Sharma   30         IT       Developer   74000
# 49  50      Manav Reddy   31         HR         Manager   87000
#
#     YearsAtCompany  PerformanceScore   Location    HireDate
# 45               5               8.6  Bangalore  2017-11-09
# 46               3               7.9    Chennai  2019-03-12
# 47               7               9.3      Delhi  2015-12-05
# 48               4               8.2       Pune  2018-07-18
# 49               5               8.8  Hyderabad  2017-06-20

# %%
df.describe()
# Out:
#              ID        Age         Salary  YearsAtCompany  PerformanceScore
# count  50.00000  50.000000      50.000000       50.000000         50.000000
# mean   25.50000  30.300000   77420.000000        4.120000          8.378000
# std    14.57738   2.130919   14891.567262        1.520473          0.609547
# min     1.00000  27.000000   55000.000000        2.000000          7.200000
# 25%    13.25000  29.000000   66250.000000        3.000000          7.900000
# 50%    25.50000  30.000000   74500.000000        4.000000          8.250000
# 75%    37.75000  32.000000   88000.000000        5.000000          8.900000
# max    50.00000  35.000000  105000.000000        7.000000          9.500000

# %%
df["Department"].value_counts()
# Out:
# Department
# IT           19
# Finance      12
# HR           10
# Marketing     9
# Name: count, dtype: int64

# %%
df["Location"].value_counts()
# Out:
# Location
# Bangalore    9
# Delhi        9
# Pune         9
# Mumbai       8
# Chennai      8
# Hyderabad    7
# Name: count, dtype: int64

# %%
print("Average Salary:", df["Salary"].mean())
# Out:
# Average Salary: 77420.0

# %%
salary_array = np.array(df["Salary"])

print("Max Salary:", np.max(salary_array))
print("Min Salary:", np.min(salary_array))
print("Salary Standard Deviation:", np.std(salary_array))
# Out:
# Max Salary: 105000
# Min Salary: 55000
# Salary Standard Deviation: 14741.899470556704

# %%
age = np.array(df["Age"])

# %%
np.max(experience)
np.min(experience)
# Out:
# np.float64(7.2)

# %%
salary_array[salary_array > 90000]
# Out:
# array([105000,  95000,  98000,  99000, 102000,  97000, 104000,  96000,
#         99000, 101000,  98000])

# %%
experience = np.array(df["PerformanceScore"])

# %%
experience[experience >= 5]
# Out:
# array([8.5, 9. , 7.5, 9.5, 8. , 8.2, 9. , 7.8, 8.7, 8.9, 7.2, 8. , 8.8,
#        7.9, 9.2, 8.1, 8.5, 7.6, 9. , 9.3, 7.8, 8.4, 7.3, 8.9, 8.2, 7.7,
#        9.1, 8.5, 8. , 9.4, 7.8, 8.2, 8.1, 8.9, 7.6, 9. , 8.7, 8. , 7.9,
#        9.2, 8.3, 7.8, 9.1, 8. , 7.5, 8.6, 7.9, 9.3, 8.2, 8.8])

# %%
dept_count = df["Department"].value_counts()

plt.bar(dept_count.index, dept_count.values)
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.title("Department-wise Employee Count")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df["Salary"])
plt.xlabel("Employee Index")
plt.ylabel("Salary")
plt.title("Salary Sine Wave")
plt.show()

# %%
plt.scatter(df["PerformanceScore"], df["Salary"])
plt.xlabel("PerformanceScore" )
plt.ylabel("Salary")
plt.title("PerformanceScore vs Salary")
plt.show()
